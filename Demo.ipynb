# %%
from PIL import Image
# import numpy as np
import matplotlib.pyplot as plt

# !python main.py evaluation --batch_size=200 --latent_dim=8 --max_epoch=100 --use_gpu=False
# Out:
# ...
# User config:
# model : VAE
# encoder_hidden_width : 1024
# decoder_hidden_width : 1024
# latent_dim : 8
# in_d : 784
# load_model_path : None
# batch_size : 200
# use_gpu : False
# num_workers : 0
# print_freq : 100
# result_fname : result.csv
# max_epoch : 100
# lr : 0.001
# lr_decay : 0.5
# weight_decay : 0.0
# ...
# initial var_loss = 547.92303
# 300it [00:25, 11.82it/s]
#   - epoch #0, var_loss=147.70364
# 300it [00:33,  8.84it/s]
#   - epoch #1, var_loss=148.13046
# 300it [00:37,  7.95it/s]
#   - epoch #2, var_loss=140.27824
# 300it [00:28, 10.44it/s]
#   - epoch #3, var_loss=132.95120
# 300it [00:29, 10.27it/s]
#   - epoch #4, var_loss=129.76689
# 300it [00:29, 10.02it/s]
#   - epoch #5, var_loss=124.37309
# 300it [00:25, 11.97it/s]
#   - epoch #6, var_loss=127.21914
# 300it [00:22, 13.06it/s]
#   - epoch #7, var_loss=124.48013
# 300it [00:21, 13.69it/s]
#   - epoch #8, var_loss=117.84784
# 300it [00:22, 13.63it/s]
#   - epoch #9, var_loss=114.40867
# 300it [00:22, 13.34it/s]
# ...

# %%
Image.open('figures/ground.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=242x242 at 0x7F1030E2DA90>

# %%
Image.open('figures/recover.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=242x242 at 0x7F1005BB6050>

# %%
Image.open('figures/noise.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=242x242 at 0x7F1005BB6350>

# %%
hist_loss = np.loadtxt('figures/loss.csv', delimiter=',')
iters = np.arange(hist_loss.size)

plt.plot(iters, hist_loss)
plt.xlabel('iters', fontsize=16)
plt.ylabel('loss', fontsize=16)
plt.title('Variational loss of training', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Variational loss of training')
