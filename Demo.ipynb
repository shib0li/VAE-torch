# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# !python main.py evaluation --batch_size=200 --latent_dim=8 --max_epoch=100 --use_gpu=True
# Out:
# =======================
# User config:
# model : VAE
# encoder_hidden_width : 1024
# decoder_hidden_width : 1024
# latent_dim : 8
# in_d : 784
# load_model_path : None
# batch_size : 200
# use_gpu : True
# num_workers : 0
# print_freq : 100
# result_fname : result.csv
# max_epoch : 100
# lr : 0.001
# lr_decay : 0.5
# weight_decay : 0.0
# =======================
# initial var_loss = 549.06165
# 300it [00:11, 27.23it/s]
#   - epoch #0, var_loss=150.83092
# 300it [00:11, 27.06it/s]
#   - epoch #1, var_loss=144.41551
# 300it [00:10, 27.60it/s]
#   - epoch #2, var_loss=137.72516
# 300it [00:10, 27.53it/s]
#   - epoch #3, var_loss=130.41014
# 300it [00:10, 27.60it/s]
#   - epoch #4, var_loss=133.51280
# 300it [00:10, 27.40it/s]
#   - epoch #5, var_loss=123.32095
# 300it [00:10, 27.30it/s]
#   - epoch #6, var_loss=122.08204
# 300it [00:11, 27.22it/s]
#   - epoch #7, var_loss=120.71346
# 300it [00:10, 27.31it/s]
#   - epoch #8, var_loss=119.22783
# 300it [00:11, 27.00it/s]
#   - epoch #9, var_loss=120.88836
# 300it [00:11, 26.34it/s]
#   - epoch #10, var_loss=120.71188
# 300it [00:10, 27.62it/s]
#   - epoch #11, var_loss=106.91566
# 300it [00:11, 27.24it/s]
#   - epoch #12, var_loss=117.05465
# 300it [00:10, 27.78it/s]
#   - epoch #13, var_loss=115.88966
# 300it [00:11, 27.18it/s]
#   - epoch #14, var_loss=116.47211
# 300it [00:10, 27.36it/s]
#   - epoch #15, var_loss=111.49445
# 300it [00:10, 27.92it/s]
#   - epoch #16, var_loss=112.91302
# 300it [00:11, 27.21it/s]
#   - epoch #17, var_loss=113.10471
# 300it [00:10, 27.43it/s]
#   - epoch #18, var_loss=113.03266
# 300it [00:10, 27.85it/s]
#   - epoch #19, var_loss=107.52857
# 300it [00:10, 27.45it/s]
#   - epoch #20, var_loss=111.67149
# 300it [00:10, 27.78it/s]
#   - epoch #21, var_loss=108.78067
# 300it [00:10, 27.54it/s]
#   - epoch #22, var_loss=109.36018
# 300it [00:10, 27.74it/s]
#   - epoch #23, var_loss=108.84975
# 300it [00:11, 26.99it/s]
#   - epoch #24, var_loss=105.97594
# 300it [00:10, 27.96it/s]
#   - epoch #25, var_loss=113.72176
# 300it [00:10, 27.57it/s]
#   - epoch #26, var_loss=108.82068
# 300it [00:11, 27.19it/s]
#   - epoch #27, var_loss=109.54559
# 300it [00:11, 27.25it/s]
#   - epoch #28, var_loss=109.36947
# 300it [00:11, 26.91it/s]
#   - epoch #29, var_loss=106.99472
# 300it [00:11, 27.15it/s]
#   - epoch #30, var_loss=105.50283
# 300it [00:11, 26.51it/s]
#   - epoch #31, var_loss=107.77760
# 300it [00:11, 26.45it/s]
#   - epoch #32, var_loss=113.57451
# 300it [00:11, 27.07it/s]
#   - epoch #33, var_loss=110.35505
# 300it [00:10, 27.28it/s]
#   - epoch #34, var_loss=108.93896
# 300it [00:10, 27.69it/s]
#   - epoch #35, var_loss=106.31863
# 300it [00:10, 27.36it/s]
#   - epoch #36, var_loss=107.00713
# 300it [00:10, 27.46it/s]
#   - epoch #37, var_loss=111.37484
# 300it [00:11, 26.88it/s]
#   - epoch #38, var_loss=107.76418
# 300it [00:10, 27.60it/s]
#   - epoch #39, var_loss=109.65411
# 300it [00:11, 26.90it/s]
#   - epoch #40, var_loss=109.43668
# 300it [00:10, 27.31it/s]
#   - epoch #41, var_loss=104.08705
# 300it [00:11, 27.05it/s]
#   - epoch #42, var_loss=105.06184
# 300it [00:10, 27.30it/s]
#   - epoch #43, var_loss=105.44958
# 300it [00:10, 27.55it/s]
#   - epoch #44, var_loss=112.06573
# 300it [00:10, 27.60it/s]
#   - epoch #45, var_loss=108.41553
# 300it [00:11, 27.25it/s]
#   - epoch #46, var_loss=107.67146
# 300it [00:11, 27.03it/s]
#   - epoch #47, var_loss=103.93650
# 300it [00:10, 27.50it/s]
#   - epoch #48, var_loss=106.83125
# 300it [00:10, 27.71it/s]
#   - epoch #49, var_loss=111.04247
# 300it [00:11, 27.02it/s]
#   - epoch #50, var_loss=108.89447
# 300it [00:11, 27.20it/s]
#   - epoch #51, var_loss=106.46068
# 300it [00:11, 27.14it/s]
#   - epoch #52, var_loss=107.68263
# 300it [00:11, 26.93it/s]
#   - epoch #53, var_loss=105.36244
# 300it [00:10, 27.85it/s]
#   - epoch #54, var_loss=103.23637
# 300it [00:10, 27.86it/s]
#   - epoch #55, var_loss=105.05344
# 300it [00:10, 27.84it/s]
#   - epoch #56, var_loss=107.60867
# 300it [00:11, 27.19it/s]
#   - epoch #57, var_loss=108.55873
# 300it [00:10, 27.51it/s]
#   - epoch #58, var_loss=105.39861
# 300it [00:10, 27.31it/s]
#   - epoch #59, var_loss=103.01636
# 300it [00:10, 27.43it/s]
#   - epoch #60, var_loss=104.88750
# 300it [00:10, 27.64it/s]
#   - epoch #61, var_loss=104.98459
# 300it [00:10, 28.08it/s]
#   - epoch #62, var_loss=107.50516
# 300it [00:10, 27.99it/s]
#   - epoch #63, var_loss=109.29282
# 300it [00:11, 27.14it/s]
#   - epoch #64, var_loss=107.46622
# 300it [00:10, 27.48it/s]
#   - epoch #65, var_loss=109.40571
# 300it [00:10, 27.53it/s]
#   - epoch #66, var_loss=105.98961
# 300it [00:10, 27.67it/s]
#   - epoch #67, var_loss=107.19822
# 300it [00:10, 27.68it/s]
#   - epoch #68, var_loss=104.34174
# 300it [00:10, 27.58it/s]
#   - epoch #69, var_loss=107.39391
# 300it [00:11, 27.20it/s]
#   - epoch #70, var_loss=107.70631
# 300it [00:11, 27.19it/s]
#   - epoch #71, var_loss=104.89120
# 300it [00:10, 27.69it/s]
#   - epoch #72, var_loss=104.76381
# 300it [00:10, 27.69it/s]
#   - epoch #73, var_loss=100.89516
# 300it [00:10, 27.47it/s]
#   - epoch #74, var_loss=104.47665
# 300it [00:11, 26.77it/s]
#   - epoch #75, var_loss=104.12582
# 300it [00:10, 27.48it/s]
#   - epoch #76, var_loss=105.69295
# 300it [00:10, 27.31it/s]
#   - epoch #77, var_loss=102.45767
# 300it [00:11, 27.17it/s]
#   - epoch #78, var_loss=102.51017
# 300it [00:10, 27.34it/s]
#   - epoch #79, var_loss=103.35352
# 300it [00:10, 27.48it/s]
#   - epoch #80, var_loss=103.27562
# 300it [00:10, 27.30it/s]
#   - epoch #81, var_loss=99.15549
# 300it [00:11, 26.71it/s]
#   - epoch #82, var_loss=106.26625
# 300it [00:10, 27.31it/s]
#   - epoch #83, var_loss=102.47321
# 300it [00:11, 26.92it/s]
#   - epoch #84, var_loss=101.94846
# 300it [00:11, 27.07it/s]
#   - epoch #85, var_loss=106.02682
# 300it [00:11, 27.24it/s]
#   - epoch #86, var_loss=107.76746
# 300it [00:11, 26.73it/s]
#   - epoch #87, var_loss=102.61378
# 300it [00:10, 27.41it/s]
#   - epoch #88, var_loss=101.60517
# 300it [00:11, 27.13it/s]
#   - epoch #89, var_loss=102.52708
# 300it [00:11, 27.27it/s]
#   - epoch #90, var_loss=104.74680
# 300it [00:10, 27.46it/s]
#   - epoch #91, var_loss=104.52827
# 300it [00:10, 27.82it/s]
#   - epoch #92, var_loss=102.04224
# 300it [00:10, 28.02it/s]
#   - epoch #93, var_loss=104.39995
# 300it [00:10, 27.92it/s]
#   - epoch #94, var_loss=105.33519
# 300it [00:10, 27.41it/s]
#   - epoch #95, var_loss=103.54366
# 300it [00:11, 26.73it/s]
#   - epoch #96, var_loss=101.78410
# 300it [00:11, 26.17it/s]
#   - epoch #97, var_loss=102.86818
# 300it [00:10, 27.34it/s]
#   - epoch #98, var_loss=106.40958
# 300it [00:11, 26.64it/s]
#   - epoch #99, var_loss=105.09605

# %%
Image.open('figures/ground.png')

# %%
Image.open('figures/recover.png')

# %%
Image.open('figures/noise.png')

# %%
hist_loss = np.loadtxt('figures/loss.csv', delimiter=',')
iters = np.arange(hist_loss.size)

plt.plot(iters, hist_loss)
plt.xlabel('iters', fontsize=16)
plt.ylabel('loss', fontsize=16)
plt.title('Variational loss of training', fontsize=20)
